# %% [markdown]
# ### 7-1．データ理解
# #### Janomeを使った形態素解析

# %%
# ファイルオープン
f = open('./data/it-life-hack/it-life-hack-6292880.txt', encoding='utf-8')

# ファイルの読み込み
text = f.read()
# テキストの確認
print(text)

# ファイルクローズ
f.close()
# Out:
# http://news.livedoor.com/article/detail/6292880/
# 2012-02-19T13:00:00+0900
# 旧式Macで禁断のパワーアップ！最新PCやソフトを一挙にチェック【ITフラッシュバック】
# テレビやTwitterと連携できるパソコンや、プロセッサや切り替わるパソコンなど、面白いパソコンが次から次へと登場した。旧式Macの禁断ともいえるパワーアップ方法から、NECの最新PC、話題のThinkPad X1 Hybrid、新セキュリティソフトまで一挙に紹介しよう。
#
# ■インテル SSD 520をMacに装着！旧式Macはどれほど高速化するのか (上)
# インテルが最新SSD「520シリーズ」を発売した。現行SSDの中でもトップクラスの性能を誇る同製品を、旧型Macの高速化を図るというポイントでレビューしてみた。少し風変わりなレビューとなるが、どの程度の効果があるか、期待大である。
#
#
# ■http://itlifehack.jp/archives/6716997.html
# ThinkPad X1 Hybridは使用するCPUがx86(インテルCore iなど)からARMに切り替わるハイブリッドなPCだが、これと同時にOSも切り替わる。
#
#
# ■初期費用、更新費用ともに無料！ジャストシステム、ヤモリが目印のセキュリティソフト
# 現在では、多くのユーザーがパソコンにセキュリティソフトを導入しているが、その過半数は毎年5,000円程度かかる更新費用やその手続きについて不満を持っている。有料ソフトを利用するユーザーの約8割は無料のセキュリティソフトを知っているにもかかわらず、性能面で劣るのではという不安から導入を控えているという状況にある。
#
#
# ■テレビの新しい楽しみ方を提案！NECの春PCはTVとTwitterの連携
# NECは2012年2月14日、個人向けデスクトップパソコン「VALUESTAR」シリーズ3タイプ16モデルを2月16日より販売すると発表した。新商品では、よりパワフルになった録画機能に加え、TV視聴・録画機能に業界で初めて人気のTwitterを連携させた「SmartVisionつぶやきプラス」を追加するなど、TVパソコンならではの機能を搭載。スマートフォン、ホームネットワーク対応も強化し、「安心・簡単・快適」なデジタルエンターテイメントの提案として、主要モデルに対し以下の強化を行った。
#
#
# ■まるでお祭りの出荷式！レッツノートSX1の出荷が始まる
# 2月24日に発売されるLet’snote SX1/NX1の出荷式が2月8日に国内製造拠点の神戸工場で行われた。同社のパソコンとして初めてとなる出荷式で、この製品への力の入れようがわかる。
#
#
#
#
#
# 【エプソン純正インク】インクカートリッジ 6色セット IC6CL50
# エプソン
# 販売元：Amazon.co.jp
# クチコミを見る

# %%
# Janomeのインストール
# !pip install janome
# Out:
# Collecting janome
#   Downloading https://files.pythonhosted.org/packages/a0/af/a57956e98b26beebc4efe20c3f5b482f0b4e091f546bfd90a96678da2f1c/Janome-0.3.7-py27.py3-none-any.whl (20.7MB)
#     100% |████████████████████████████████| 20.7MB 291kB/s
# Installing collected packages: janome
# Successfully installed janome-0.3.7

# %%
from janome.tokenizer import Tokenizer

# オブジェクト生成
t = Tokenizer()
# 形態素解析
for token in t.tokenize(text):
    print(token)
# Out:
# http	名詞,固有名詞,組織,*,*,*,http,*,*
# ://	名詞,サ変接続,*,*,*,*,://,*,*
# news	名詞,一般,*,*,*,*,news,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
# livedoor	名詞,一般,*,*,*,*,livedoor,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
# com	名詞,一般,*,*,*,*,com,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# article	名詞,一般,*,*,*,*,article,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# detail	名詞,一般,*,*,*,*,detail,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# 6292880	名詞,数,*,*,*,*,6292880,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 2012	名詞,数,*,*,*,*,2012,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
# 02	名詞,数,*,*,*,*,02,*,*
# -	名詞,サ変接続,*,*,*,*,-,*,*
# 19	名詞,数,*,*,*,*,19,*,*
# T	名詞,一般,*,*,*,*,T,*,*
# 13	名詞,数,*,*,*,*,13,*,*
# :	名詞,サ変接続,*,*,*,*,:,*,*
# 00	名詞,数,*,*,*,*,00,*,*
# :	名詞,サ変接続,*,*,*,*,:,*,*
# 00	名詞,数,*,*,*,*,00,*,*
# +	名詞,サ変接続,*,*,*,*,+,*,*
# 0900	名詞,数,*,*,*,*,0900,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 旧式	名詞,一般,*,*,*,*,旧式,キュウシキ,キューシキ
# Mac	名詞,一般,*,*,*,*,Mac,*,*
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 禁断	名詞,サ変接続,*,*,*,*,禁断,キンダン,キンダン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# パワーアップ	名詞,サ変接続,*,*,*,*,パワーアップ,パワーアップ,パワーアップ
# ！	記号,一般,*,*,*,*,！,！,！
# 最新	名詞,一般,*,*,*,*,最新,サイシン,サイシン
# PC	名詞,一般,*,*,*,*,PC,*,*
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 一挙	名詞,副詞可能,*,*,*,*,一挙,イッキョ,イッキョ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# チェック	名詞,サ変接続,*,*,*,*,チェック,チェック,チェック
# 【	記号,括弧開,*,*,*,*,【,【,【
# IT	名詞,固有名詞,組織,*,*,*,IT,*,*
# フラッシュ	名詞,一般,*,*,*,*,フラッシュ,フラッシュ,フラッシュ
# バック	名詞,サ変接続,*,*,*,*,バック,バック,バック
# 】	記号,括弧閉,*,*,*,*,】,】,】
#
# 	記号,空白,*,*,*,*,
# ,*,*
# テレビ	名詞,一般,*,*,*,*,テレビ,テレビ,テレビ
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# Twitter	名詞,固有名詞,組織,*,*,*,Twitter,*,*
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 連携	名詞,サ変接続,*,*,*,*,連携,レンケイ,レンケイ
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# 、	記号,読点,*,*,*,*,、,、,、
# プロセッサ	名詞,一般,*,*,*,*,プロセッサ,プロセッサ,プロセッサ
# や	助詞,係助詞,*,*,*,*,や,ヤ,ヤ
# 切り替わる	動詞,自立,*,*,五段・ラ行,基本形,切り替わる,キリカワル,キリカワル
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# 、	記号,読点,*,*,*,*,、,、,、
# 面白い	形容詞,自立,*,*,形容詞・アウオ段,基本形,面白い,オモシロイ,オモシロイ
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 次	名詞,一般,*,*,*,*,次,ツギ,ツギ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 次	名詞,一般,*,*,*,*,次,ツギ,ツギ
# へ	助詞,格助詞,一般,*,*,*,へ,ヘ,エ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 登場	名詞,サ変接続,*,*,*,*,登場,トウジョウ,トージョー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# 旧式	名詞,一般,*,*,*,*,旧式,キュウシキ,キューシキ
# Mac	名詞,一般,*,*,*,*,Mac,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 禁断	名詞,サ変接続,*,*,*,*,禁断,キンダン,キンダン
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# いえる	動詞,自立,*,*,一段,基本形,いえる,イエル,イエル
# パワーアップ	名詞,サ変接続,*,*,*,*,パワーアップ,パワーアップ,パワーアップ
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 、	記号,読点,*,*,*,*,、,、,、
# NEC	名詞,固有名詞,組織,*,*,*,NEC,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 最新	名詞,一般,*,*,*,*,最新,サイシン,サイシン
# PC	名詞,一般,*,*,*,*,PC,*,*
# 、	記号,読点,*,*,*,*,、,、,、
# 話題	名詞,一般,*,*,*,*,話題,ワダイ,ワダイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ThinkPad	名詞,一般,*,*,*,*,ThinkPad,*,*
#  	記号,空白,*,*,*,*, ,*,*
# X	名詞,一般,*,*,*,*,X,*,*
# 1	名詞,数,*,*,*,*,1,*,*
#  	記号,空白,*,*,*,*, ,*,*
# Hybrid	名詞,固有名詞,組織,*,*,*,Hybrid,*,*
# 、	記号,読点,*,*,*,*,、,、,、
# 新	接頭詞,名詞接続,*,*,*,*,新,シン,シン
# セキュリティ	名詞,一般,*,*,*,*,セキュリティ,セキュリティ,セキュリティ
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# まで	助詞,副助詞,*,*,*,*,まで,マデ,マデ
# 一挙	名詞,副詞可能,*,*,*,*,一挙,イッキョ,イッキョ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 紹介	名詞,サ変接続,*,*,*,*,紹介,ショウカイ,ショーカイ
# しよ	動詞,自立,*,*,サ変・スル,未然ウ接続,する,シヨ,シヨ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ■	記号,一般,*,*,*,*,■,■,■
# インテル	名詞,固有名詞,組織,*,*,*,インテル,インテル,インテル
#  	記号,空白,*,*,*,*, ,*,*
# SSD	名詞,固有名詞,組織,*,*,*,SSD,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 520	名詞,数,*,*,*,*,520,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# Mac	名詞,一般,*,*,*,*,Mac,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 装着	名詞,サ変接続,*,*,*,*,装着,ソウチャク,ソーチャク
# ！	記号,一般,*,*,*,*,！,！,！
# 旧式	名詞,一般,*,*,*,*,旧式,キュウシキ,キューシキ
# Mac	名詞,一般,*,*,*,*,Mac,*,*
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# どれ	名詞,代名詞,一般,*,*,*,どれ,ドレ,ドレ
# ほど	助詞,副助詞,*,*,*,*,ほど,ホド,ホド
# 高速	名詞,一般,*,*,*,*,高速,コウソク,コーソク
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
#  	記号,空白,*,*,*,*, ,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 上	名詞,接尾,副詞可能,*,*,*,上,ジョウ,ジョー
# )	名詞,サ変接続,*,*,*,*,),*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# インテル	名詞,固有名詞,組織,*,*,*,インテル,インテル,インテル
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 最新	名詞,一般,*,*,*,*,最新,サイシン,サイシン
# SSD	名詞,一般,*,*,*,*,SSD,*,*
# 「	記号,括弧開,*,*,*,*,「,「,「
# 520	名詞,数,*,*,*,*,520,*,*
# シリーズ	名詞,一般,*,*,*,*,シリーズ,シリーズ,シリーズ
# 」	記号,括弧閉,*,*,*,*,」,」,」
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 発売	名詞,サ変接続,*,*,*,*,発売,ハツバイ,ハツバイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# 現行	名詞,一般,*,*,*,*,現行,ゲンコウ,ゲンコー
# SSD	名詞,一般,*,*,*,*,SSD,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# でも	助詞,副助詞,*,*,*,*,でも,デモ,デモ
# トップクラス	名詞,一般,*,*,*,*,トップクラス,トップクラス,トップクラス
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 性能	名詞,一般,*,*,*,*,性能,セイノウ,セイノー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 誇る	動詞,自立,*,*,五段・ラ行,基本形,誇る,ホコル,ホコル
# 同	接頭詞,名詞接続,*,*,*,*,同,ドウ,ドー
# 製品	名詞,一般,*,*,*,*,製品,セイヒン,セイヒン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 、	記号,読点,*,*,*,*,、,、,、
# 旧型	名詞,一般,*,*,*,*,旧型,キュウガタ,キューガタ
# Mac	名詞,一般,*,*,*,*,Mac,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 高速	名詞,一般,*,*,*,*,高速,コウソク,コーソク
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 図る	動詞,自立,*,*,五段・ラ行,基本形,図る,ハカル,ハカル
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# ポイント	名詞,一般,*,*,*,*,ポイント,ポイント,ポイント
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# み	動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# 少し	副詞,助詞類接続,*,*,*,*,少し,スコシ,スコシ
# 風変わり	名詞,形容動詞語幹,*,*,*,*,風変わり,フウガワリ,フーガワリ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# どの	連体詞,*,*,*,*,*,どの,ドノ,ドノ
# 程度	名詞,一般,*,*,*,*,程度,テイド,テイド
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 効果	名詞,一般,*,*,*,*,効果,コウカ,コーカ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ある	動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 、	記号,読点,*,*,*,*,、,、,、
# 期待	名詞,サ変接続,*,*,*,*,期待,キタイ,キタイ
# 大	名詞,接尾,一般,*,*,*,大,ダイ,ダイ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# ある	助動詞,*,*,*,五段・ラ行アル,基本形,ある,アル,アル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#
# 	記号,空白,*,*,*,*,
#
#
# ,*,*
# ■	記号,一般,*,*,*,*,■,■,■
# http	名詞,固有名詞,組織,*,*,*,http,*,*
# ://	名詞,サ変接続,*,*,*,*,://,*,*
# itlifehack	名詞,一般,*,*,*,*,itlifehack,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
# jp	名詞,一般,*,*,*,*,jp,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# archives	名詞,一般,*,*,*,*,archives,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# 6716997	名詞,数,*,*,*,*,6716997,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
# html	名詞,固有名詞,組織,*,*,*,html,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ThinkPad	名詞,固有名詞,組織,*,*,*,ThinkPad,*,*
#  	記号,空白,*,*,*,*, ,*,*
# X	名詞,一般,*,*,*,*,X,*,*
# 1	名詞,数,*,*,*,*,1,*,*
#  	記号,空白,*,*,*,*, ,*,*
# Hybrid	名詞,固有名詞,組織,*,*,*,Hybrid,*,*
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 使用	名詞,サ変接続,*,*,*,*,使用,シヨウ,シヨー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# CPU	名詞,固有名詞,組織,*,*,*,CPU,*,*
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# x	名詞,一般,*,*,*,*,x,*,*
# 86	名詞,数,*,*,*,*,86,*,*
# (	名詞,サ変接続,*,*,*,*,(,*,*
# インテル	名詞,固有名詞,組織,*,*,*,インテル,インテル,インテル
# Core	名詞,一般,*,*,*,*,Core,*,*
#  	記号,空白,*,*,*,*, ,*,*
# i	名詞,固有名詞,組織,*,*,*,i,*,*
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# )	名詞,サ変接続,*,*,*,*,),*,*
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# ARM	名詞,一般,*,*,*,*,ARM,*,*
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 切り替わる	動詞,自立,*,*,五段・ラ行,基本形,切り替わる,キリカワル,キリカワル
# ハイブリッド	名詞,一般,*,*,*,*,ハイブリッド,ハイブリッド,ハイブリッド
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# PC	名詞,一般,*,*,*,*,PC,*,*
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# 同時に	副詞,一般,*,*,*,*,同時に,ドウジニ,ドージニ
# OS	名詞,一般,*,*,*,*,OS,*,*
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 切り替わる	動詞,自立,*,*,五段・ラ行,基本形,切り替わる,キリカワル,キリカワル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#
# 	記号,空白,*,*,*,*,
#
#
# ,*,*
# ■	記号,一般,*,*,*,*,■,■,■
# 初期	名詞,一般,*,*,*,*,初期,ショキ,ショキ
# 費用	名詞,一般,*,*,*,*,費用,ヒヨウ,ヒヨー
# 、	記号,読点,*,*,*,*,、,、,、
# 更新	名詞,サ変接続,*,*,*,*,更新,コウシン,コーシン
# 費用	名詞,一般,*,*,*,*,費用,ヒヨウ,ヒヨー
# とも	名詞,接尾,一般,*,*,*,とも,トモ,トモ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 無料	名詞,一般,*,*,*,*,無料,ムリョウ,ムリョー
# ！	記号,一般,*,*,*,*,！,！,！
# ジャストシステム	名詞,固有名詞,組織,*,*,*,ジャストシステム,ジャストシステム,ジャストシステム
# 、	記号,読点,*,*,*,*,、,、,、
# ヤモリ	名詞,一般,*,*,*,*,ヤモリ,ヤモリ,ヤモリ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 目印	名詞,サ変接続,*,*,*,*,目印,メジルシ,メジルシ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# セキュリティ	名詞,一般,*,*,*,*,セキュリティ,セキュリティ,セキュリティ
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 現在	名詞,副詞可能,*,*,*,*,現在,ゲンザイ,ゲンザイ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# 多く	名詞,副詞可能,*,*,*,*,多く,オオク,オーク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ユーザー	名詞,一般,*,*,*,*,ユーザー,ユーザー,ユーザー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# セキュリティ	名詞,一般,*,*,*,*,セキュリティ,セキュリティ,セキュリティ
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 導入	名詞,サ変接続,*,*,*,*,導入,ドウニュウ,ドーニュー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# その	連体詞,*,*,*,*,*,その,ソノ,ソノ
# 過半数	名詞,一般,*,*,*,*,過半数,カハンスウ,カハンスー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 毎年	名詞,副詞可能,*,*,*,*,毎年,マイトシ,マイトシ
# 5	名詞,数,*,*,*,*,5,*,*
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 000	名詞,数,*,*,*,*,000,*,*
# 円	名詞,接尾,助数詞,*,*,*,円,エン,エン
# 程度	名詞,接尾,一般,*,*,*,程度,テイド,テイド
# かかる	動詞,自立,*,*,五段・ラ行,基本形,かかる,カカル,カカル
# 更新	名詞,サ変接続,*,*,*,*,更新,コウシン,コーシン
# 費用	名詞,一般,*,*,*,*,費用,ヒヨウ,ヒヨー
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# その	連体詞,*,*,*,*,*,その,ソノ,ソノ
# 手続き	名詞,サ変接続,*,*,*,*,手続き,テツヅキ,テツズキ
# について	助詞,格助詞,連語,*,*,*,について,ニツイテ,ニツイテ
# 不満	名詞,一般,*,*,*,*,不満,フマン,フマン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 持っ	動詞,自立,*,*,五段・タ行,連用タ接続,持つ,モッ,モッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# 有料	名詞,一般,*,*,*,*,有料,ユウリョウ,ユーリョー
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 利用	名詞,サ変接続,*,*,*,*,利用,リヨウ,リヨー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# ユーザー	名詞,一般,*,*,*,*,ユーザー,ユーザー,ユーザー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 約	接頭詞,数接続,*,*,*,*,約,ヤク,ヤク
# 8	名詞,数,*,*,*,*,8,*,*
# 割	名詞,接尾,助数詞,*,*,*,割,ワリ,ワリ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 無料	名詞,一般,*,*,*,*,無料,ムリョウ,ムリョー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# セキュリティ	名詞,一般,*,*,*,*,セキュリティ,セキュリティ,セキュリティ
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 知っ	動詞,自立,*,*,五段・ラ行,連用タ接続,知る,シッ,シッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# かかわら	動詞,自立,*,*,五段・ラ行,未然形,かかわる,カカワラ,カカワラ
# ず	助動詞,*,*,*,特殊・ヌ,連用ニ接続,ぬ,ズ,ズ
# 、	記号,読点,*,*,*,*,、,、,、
# 性能	名詞,一般,*,*,*,*,性能,セイノウ,セイノー
# 面	名詞,接尾,一般,*,*,*,面,メン,メン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 劣る	動詞,自立,*,*,五段・ラ行,基本形,劣る,オトル,オトル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# 不安	名詞,形容動詞語幹,*,*,*,*,不安,フアン,フアン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 導入	名詞,サ変接続,*,*,*,*,導入,ドウニュウ,ドーニュー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 控え	動詞,自立,*,*,一段,連用形,控える,ヒカエ,ヒカエ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# 状況	名詞,一般,*,*,*,*,状況,ジョウキョウ,ジョーキョー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# ある	動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#
# 	記号,空白,*,*,*,*,
#
#
# ,*,*
# ■	記号,一般,*,*,*,*,■,■,■
# テレビ	名詞,一般,*,*,*,*,テレビ,テレビ,テレビ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# 楽しみ	動詞,自立,*,*,五段・マ行,連用形,楽しむ,タノシミ,タノシミ
# 方	名詞,接尾,特殊,*,*,*,方,カタ,カタ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 提案	名詞,サ変接続,*,*,*,*,提案,テイアン,テイアン
# ！	記号,一般,*,*,*,*,！,！,！
# NEC	名詞,固有名詞,組織,*,*,*,NEC,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 春	名詞,一般,*,*,*,*,春,ハル,ハル
# PC	名詞,一般,*,*,*,*,PC,*,*
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# TV	名詞,固有名詞,組織,*,*,*,TV,*,*
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# Twitter	名詞,一般,*,*,*,*,Twitter,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 連携	名詞,サ変接続,*,*,*,*,連携,レンケイ,レンケイ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# NEC	名詞,固有名詞,組織,*,*,*,NEC,*,*
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 2012	名詞,数,*,*,*,*,2012,*,*
# 年	名詞,接尾,助数詞,*,*,*,年,ネン,ネン
# 2	名詞,数,*,*,*,*,2,*,*
# 月	名詞,一般,*,*,*,*,月,ツキ,ツキ
# 14	名詞,数,*,*,*,*,14,*,*
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# 、	記号,読点,*,*,*,*,、,、,、
# 個人	名詞,一般,*,*,*,*,個人,コジン,コジン
# 向け	名詞,接尾,一般,*,*,*,向け,ムケ,ムケ
# デスク	名詞,一般,*,*,*,*,デスク,デスク,デスク
# トップ	名詞,一般,*,*,*,*,トップ,トップ,トップ
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# 「	記号,括弧開,*,*,*,*,「,「,「
# VALUESTAR	名詞,固有名詞,組織,*,*,*,VALUESTAR,*,*
# 」	記号,括弧閉,*,*,*,*,」,」,」
# シリーズ	名詞,一般,*,*,*,*,シリーズ,シリーズ,シリーズ
# 3	名詞,数,*,*,*,*,3,*,*
# タイプ	名詞,一般,*,*,*,*,タイプ,タイプ,タイプ
# 16	名詞,数,*,*,*,*,16,*,*
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 2	名詞,数,*,*,*,*,2,*,*
# 月	名詞,一般,*,*,*,*,月,ツキ,ツキ
# 16	名詞,数,*,*,*,*,16,*,*
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# より	助詞,格助詞,一般,*,*,*,より,ヨリ,ヨリ
# 販売	名詞,サ変接続,*,*,*,*,販売,ハンバイ,ハンバイ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 発表	名詞,サ変接続,*,*,*,*,発表,ハッピョウ,ハッピョー
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# 新	接頭詞,名詞接続,*,*,*,*,新,シン,シン
# 商品	名詞,一般,*,*,*,*,商品,ショウヒン,ショーヒン
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# より	副詞,一般,*,*,*,*,より,ヨリ,ヨリ
# パワフル	名詞,一般,*,*,*,*,パワフル,パワフル,パワフル
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 録画	名詞,サ変接続,*,*,*,*,録画,ロクガ,ロクガ
# 機能	名詞,サ変接続,*,*,*,*,機能,キノウ,キノー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 加え	動詞,自立,*,*,一段,連用形,加える,クワエ,クワエ
# 、	記号,読点,*,*,*,*,、,、,、
# TV	名詞,固有名詞,組織,*,*,*,TV,*,*
# 視聴	名詞,サ変接続,*,*,*,*,視聴,シチョウ,シチョー
# ・	記号,一般,*,*,*,*,・,・,・
# 録画	名詞,サ変接続,*,*,*,*,録画,ロクガ,ロクガ
# 機能	名詞,サ変接続,*,*,*,*,機能,キノウ,キノー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 業界	名詞,一般,*,*,*,*,業界,ギョウカイ,ギョーカイ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 初めて	副詞,一般,*,*,*,*,初めて,ハジメテ,ハジメテ
# 人気	名詞,一般,*,*,*,*,人気,ニンキ,ニンキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# Twitter	名詞,一般,*,*,*,*,Twitter,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 連携	名詞,サ変接続,*,*,*,*,連携,レンケイ,レンケイ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# せ	動詞,接尾,*,*,一段,連用形,せる,セ,セ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 「	記号,括弧開,*,*,*,*,「,「,「
# SmartVision	名詞,固有名詞,組織,*,*,*,SmartVision,*,*
# つぶやき	名詞,一般,*,*,*,*,つぶやき,ツブヤキ,ツブヤキ
# プラス	名詞,一般,*,*,*,*,プラス,プラス,プラス
# 」	記号,括弧閉,*,*,*,*,」,」,」
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 追加	名詞,サ変接続,*,*,*,*,追加,ツイカ,ツイカ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# 、	記号,読点,*,*,*,*,、,、,、
# TV	名詞,固有名詞,組織,*,*,*,TV,*,*
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# ならでは	名詞,接尾,一般,*,*,*,ならでは,ナラデハ,ナラデワ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 機能	名詞,サ変接続,*,*,*,*,機能,キノウ,キノー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 搭載	名詞,サ変接続,*,*,*,*,搭載,トウサイ,トーサイ
# 。	記号,句点,*,*,*,*,。,。,。
# スマート	名詞,固有名詞,人名,姓,*,*,スマート,スマート,スマート
# フォン	名詞,一般,*,*,*,*,フォン,フォン,フォン
# 、	記号,読点,*,*,*,*,、,、,、
# ホーム	名詞,一般,*,*,*,*,ホーム,ホーム,ホーム
# ネットワーク	名詞,一般,*,*,*,*,ネットワーク,ネットワーク,ネットワーク
# 対応	名詞,サ変接続,*,*,*,*,対応,タイオウ,タイオー
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 強化	名詞,サ変接続,*,*,*,*,強化,キョウカ,キョーカ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# 、	記号,読点,*,*,*,*,、,、,、
# 「	記号,括弧開,*,*,*,*,「,「,「
# 安心	名詞,サ変接続,*,*,*,*,安心,アンシン,アンシン
# ・	記号,一般,*,*,*,*,・,・,・
# 簡単	名詞,形容動詞語幹,*,*,*,*,簡単,カンタン,カンタン
# ・	記号,一般,*,*,*,*,・,・,・
# 快適	名詞,一般,*,*,*,*,快適,カイテキ,カイテキ
# 」	記号,括弧閉,*,*,*,*,」,」,」
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# デジタル	名詞,一般,*,*,*,*,デジタル,デジタル,デジタル
# エンターテイメント	名詞,一般,*,*,*,*,エンターテイメント,エンターテイメント,エンターテイメント
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 提案	名詞,サ変接続,*,*,*,*,提案,テイアン,テイアン
# として	助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# 、	記号,読点,*,*,*,*,、,、,、
# 主要	名詞,形容動詞語幹,*,*,*,*,主要,シュヨウ,シュヨー
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# に対し	助詞,格助詞,連語,*,*,*,に対し,ニタイシ,ニタイシ
# 以下	名詞,非自立,副詞可能,*,*,*,以下,イカ,イカ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 強化	名詞,サ変接続,*,*,*,*,強化,キョウカ,キョーカ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 行っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,行う,オコナッ,オコナッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#
# 	記号,空白,*,*,*,*,
#
#
# ,*,*
# ■	記号,一般,*,*,*,*,■,■,■
# まるで	副詞,一般,*,*,*,*,まるで,マルデ,マルデ
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 祭り	名詞,一般,*,*,*,*,祭り,マツリ,マツリ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 出荷	名詞,サ変接続,*,*,*,*,出荷,シュッカ,シュッカ
# 式	名詞,接尾,一般,*,*,*,式,シキ,シキ
# ！	記号,一般,*,*,*,*,！,！,！
# レッツ	名詞,固有名詞,組織,*,*,*,レッツ,レッツ,レッツ
# ノート	名詞,一般,*,*,*,*,ノート,ノート,ノート
# SX	名詞,一般,*,*,*,*,SX,*,*
# 1	名詞,数,*,*,*,*,1,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 出荷	名詞,サ変接続,*,*,*,*,出荷,シュッカ,シュッカ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 始まる	動詞,自立,*,*,五段・ラ行,基本形,始まる,ハジマル,ハジマル
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 2	名詞,数,*,*,*,*,2,*,*
# 月	名詞,一般,*,*,*,*,月,ツキ,ツキ
# 24	名詞,数,*,*,*,*,24,*,*
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 発売	名詞,サ変接続,*,*,*,*,発売,ハツバイ,ハツバイ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# Let	名詞,一般,*,*,*,*,Let,*,*
# ’	記号,括弧閉,*,*,*,*,’,’,’
# snote	名詞,固有名詞,組織,*,*,*,snote,*,*
#  	記号,空白,*,*,*,*, ,*,*
# SX	名詞,一般,*,*,*,*,SX,*,*
# 1	名詞,数,*,*,*,*,1,*,*
# /	名詞,サ変接続,*,*,*,*,/,*,*
# NX	名詞,一般,*,*,*,*,NX,*,*
# 1	名詞,数,*,*,*,*,1,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 出荷	名詞,サ変接続,*,*,*,*,出荷,シュッカ,シュッカ
# 式	名詞,接尾,一般,*,*,*,式,シキ,シキ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 2	名詞,数,*,*,*,*,2,*,*
# 月	名詞,一般,*,*,*,*,月,ツキ,ツキ
# 8	名詞,数,*,*,*,*,8,*,*
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 国内	名詞,一般,*,*,*,*,国内,コクナイ,コクナイ
# 製造	名詞,サ変接続,*,*,*,*,製造,セイゾウ,セイゾー
# 拠点	名詞,一般,*,*,*,*,拠点,キョテン,キョテン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 神戸	名詞,固有名詞,地域,一般,*,*,神戸,コウベ,コーベ
# 工場	名詞,一般,*,*,*,*,工場,コウジョウ,コージョー
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 行わ	動詞,自立,*,*,五段・ワ行促音便,未然形,行う,オコナワ,オコナワ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。	記号,句点,*,*,*,*,。,。,。
# 同社	名詞,一般,*,*,*,*,同社,ドウシャ,ドーシャ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# として	助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# 初めて	副詞,一般,*,*,*,*,初めて,ハジメテ,ハジメテ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# 出荷	名詞,サ変接続,*,*,*,*,出荷,シュッカ,シュッカ
# 式	名詞,接尾,一般,*,*,*,式,シキ,シキ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 、	記号,読点,*,*,*,*,、,、,、
# この	連体詞,*,*,*,*,*,この,コノ,コノ
# 製品	名詞,一般,*,*,*,*,製品,セイヒン,セイヒン
# へ	助詞,格助詞,一般,*,*,*,へ,ヘ,エ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 力	名詞,一般,*,*,*,*,力,チカラ,チカラ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 入れ	動詞,自立,*,*,一段,連用形,入れる,イレ,イレ
# よう	名詞,接尾,一般,*,*,*,よう,ヨウ,ヨー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# わかる	動詞,自立,*,*,五段・ラ行,基本形,わかる,ワカル,ワカル
# 。	記号,句点,*,*,*,*,。,。,。
#
#
#
#
#
#
# 	記号,空白,*,*,*,*,
#
#
#
#
#
# ,*,*
# 【	記号,括弧開,*,*,*,*,【,【,【
# エプソン	名詞,固有名詞,組織,*,*,*,エプソン,エプソン,エプソン
# 純正	名詞,一般,*,*,*,*,純正,ジュンセイ,ジュンセイ
# インク	名詞,一般,*,*,*,*,インク,インク,インク
# 】	記号,括弧閉,*,*,*,*,】,】,】
# インク	名詞,一般,*,*,*,*,インク,インク,インク
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
#  	記号,空白,*,*,*,*, ,*,*
# 6	名詞,数,*,*,*,*,6,*,*
# 色	名詞,接尾,助数詞,*,*,*,色,ショク,ショク
# セット	名詞,一般,*,*,*,*,セット,セット,セット
#  	記号,空白,*,*,*,*, ,*,*
# IC	名詞,一般,*,*,*,*,IC,*,*
# 6	名詞,数,*,*,*,*,6,*,*
# CL	名詞,一般,*,*,*,*,CL,*,*
# 50	名詞,数,*,*,*,*,50,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# エプソン	名詞,固有名詞,組織,*,*,*,エプソン,エプソン,エプソン
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 販売元	名詞,一般,*,*,*,*,販売元,ハンバイモト,ハンバイモト
# ：	記号,一般,*,*,*,*,：,：,：
# Amazon	名詞,固有名詞,組織,*,*,*,Amazon,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
# co	名詞,一般,*,*,*,*,co,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
# jp	名詞,固有名詞,組織,*,*,*,jp,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# クチコミ	名詞,一般,*,*,*,*,クチコミ,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見る	動詞,自立,*,*,一段,基本形,見る,ミル,ミル

# %% [markdown]
# #### テキストの正規化

# %%
import re

# 半角数字0～9、小文字大文字a～ZなどURLに含まれる文字列を除去
reg_text = re.sub(r'[0-9a-zA-Z]+', '', text)
reg_text = re.sub(r'[:;/+\.-]', '', reg_text)

print(reg_text)
# Out:
# 旧式で禁断のパワーアップ！最新やソフトを一挙にチェック【フラッシュバック】
# テレビやと連携できるパソコンや、プロセッサや切り替わるパソコンなど、面白いパソコンが次から次へと登場した。旧式の禁断ともいえるパワーアップ方法から、の最新、話題の  、新セキュリティソフトまで一挙に紹介しよう。
#
# ■インテル  をに装着！旧式はどれほど高速化するのか (上)
# インテルが最新「シリーズ」を発売した。現行の中でもトップクラスの性能を誇る同製品を、旧型の高速化を図るというポイントでレビューしてみた。少し風変わりなレビューとなるが、どの程度の効果があるか、期待大である。
#
#
# ■
#   は使用するが(インテル など)からに切り替わるハイブリッドなだが、これと同時にも切り替わる。
#
#
# ■初期費用、更新費用ともに無料！ジャストシステム、ヤモリが目印のセキュリティソフト
# 現在では、多くのユーザーがパソコンにセキュリティソフトを導入しているが、その過半数は毎年,円程度かかる更新費用やその手続きについて不満を持っている。有料ソフトを利用するユーザーの約割は無料のセキュリティソフトを知っているにもかかわらず、性能面で劣るのではという不安から導入を控えているという状況にある。
#
#
# ■テレビの新しい楽しみ方を提案！の春はとの連携
# は年月日、個人向けデスクトップパソコン「」シリーズタイプモデルを月日より販売すると発表した。新商品では、よりパワフルになった録画機能に加え、視聴・録画機能に業界で初めて人気のを連携させた「つぶやきプラス」を追加するなど、パソコンならではの機能を搭載。スマートフォン、ホームネットワーク対応も強化し、「安心・簡単・快適」なデジタルエンターテイメントの提案として、主要モデルに対し以下の強化を行った。
#
#
# ■まるでお祭りの出荷式！レッツノートの出荷が始まる
# 月日に発売される’ の出荷式が月日に国内製造拠点の神戸工場で行われた。同社のパソコンとして初めてとなる出荷式で、この製品への力の入れようがわかる。
#
#
#
#
#
# 【エプソン純正インク】インクカートリッジ 色セット
# エプソン
# 販売元：
# クチコミを見る

# %%
# 練習問題1
reg_text = re.sub(r'[\s\n]', '', reg_text)

print(reg_text)
# Out:
# 旧式で禁断のパワーアップ！最新やソフトを一挙にチェック【フラッシュバック】テレビやと連携できるパソコンや、プロセッサや切り替わるパソコンなど、面白いパソコンが次から次へと登場した。旧式の禁断ともいえるパワーアップ方法から、の最新、話題の、新セキュリティソフトまで一挙に紹介しよう。■インテルをに装着！旧式はどれほど高速化するのか(上)インテルが最新「シリーズ」を発売した。現行の中でもトップクラスの性能を誇る同製品を、旧型の高速化を図るというポイントでレビューしてみた。少し風変わりなレビューとなるが、どの程度の効果があるか、期待大である。■は使用するが(インテルなど)からに切り替わるハイブリッドなだが、これと同時にも切り替わる。■初期費用、更新費用ともに無料！ジャストシステム、ヤモリが目印のセキュリティソフト現在では、多くのユーザーがパソコンにセキュリティソフトを導入しているが、その過半数は毎年,円程度かかる更新費用やその手続きについて不満を持っている。有料ソフトを利用するユーザーの約割は無料のセキュリティソフトを知っているにもかかわらず、性能面で劣るのではという不安から導入を控えているという状況にある。■テレビの新しい楽しみ方を提案！の春はとの連携は年月日、個人向けデスクトップパソコン「」シリーズタイプモデルを月日より販売すると発表した。新商品では、よりパワフルになった録画機能に加え、視聴・録画機能に業界で初めて人気のを連携させた「つぶやきプラス」を追加するなど、パソコンならではの機能を搭載。スマートフォン、ホームネットワーク対応も強化し、「安心・簡単・快適」なデジタルエンターテイメントの提案として、主要モデルに対し以下の強化を行った。■まるでお祭りの出荷式！レッツノートの出荷が始まる月日に発売される’の出荷式が月日に国内製造拠点の神戸工場で行われた。同社のパソコンとして初めてとなる出荷式で、この製品への力の入れようがわかる。【エプソン純正インク】インクカートリッジ色セットエプソン販売元：クチコミを見る

# %% [markdown]
# #### 単語を品詞で抽出

# %%
from janome.analyzer import Analyzer
from janome.tokenfilter import POSKeepFilter

# 名詞の単語のみ抽出するフィルターを生成
token_filters = [POSKeepFilter(['名詞'])]
# フィルターを搭載した解析フレームワークの生成
a = Analyzer([], t, token_filters)

# フィルタ付き形態素解析
for token in a.analyze(reg_text):
    print(token)
# Out:
# 旧式	名詞,一般,*,*,*,*,旧式,キュウシキ,キューシキ
# 禁断	名詞,サ変接続,*,*,*,*,禁断,キンダン,キンダン
# パワーアップ	名詞,サ変接続,*,*,*,*,パワーアップ,パワーアップ,パワーアップ
# 最新	名詞,一般,*,*,*,*,最新,サイシン,サイシン
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# 一挙	名詞,副詞可能,*,*,*,*,一挙,イッキョ,イッキョ
# チェック	名詞,サ変接続,*,*,*,*,チェック,チェック,チェック
# フラッシュ	名詞,一般,*,*,*,*,フラッシュ,フラッシュ,フラッシュ
# バック	名詞,サ変接続,*,*,*,*,バック,バック,バック
# テレビ	名詞,一般,*,*,*,*,テレビ,テレビ,テレビ
# 連携	名詞,サ変接続,*,*,*,*,連携,レンケイ,レンケイ
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# プロセッサ	名詞,一般,*,*,*,*,プロセッサ,プロセッサ,プロセッサ
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# 次	名詞,一般,*,*,*,*,次,ツギ,ツギ
# 次	名詞,一般,*,*,*,*,次,ツギ,ツギ
# 登場	名詞,サ変接続,*,*,*,*,登場,トウジョウ,トージョー
# 旧式	名詞,一般,*,*,*,*,旧式,キュウシキ,キューシキ
# 禁断	名詞,サ変接続,*,*,*,*,禁断,キンダン,キンダン
# パワーアップ	名詞,サ変接続,*,*,*,*,パワーアップ,パワーアップ,パワーアップ
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# 最新	名詞,一般,*,*,*,*,最新,サイシン,サイシン
# 話題	名詞,一般,*,*,*,*,話題,ワダイ,ワダイ
# セキュリティ	名詞,一般,*,*,*,*,セキュリティ,セキュリティ,セキュリティ
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# 一挙	名詞,副詞可能,*,*,*,*,一挙,イッキョ,イッキョ
# 紹介	名詞,サ変接続,*,*,*,*,紹介,ショウカイ,ショーカイ
# インテル	名詞,固有名詞,組織,*,*,*,インテル,インテル,インテル
# 装着	名詞,サ変接続,*,*,*,*,装着,ソウチャク,ソーチャク
# 旧式	名詞,一般,*,*,*,*,旧式,キュウシキ,キューシキ
# どれ	名詞,代名詞,一般,*,*,*,どれ,ドレ,ドレ
# 高速	名詞,一般,*,*,*,*,高速,コウソク,コーソク
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# (	名詞,サ変接続,*,*,*,*,(,*,*
# 上	名詞,接尾,副詞可能,*,*,*,上,ジョウ,ジョー
# )	名詞,サ変接続,*,*,*,*,),*,*
# インテル	名詞,固有名詞,組織,*,*,*,インテル,インテル,インテル
# 最新	名詞,一般,*,*,*,*,最新,サイシン,サイシン
# シリーズ	名詞,一般,*,*,*,*,シリーズ,シリーズ,シリーズ
# 発売	名詞,サ変接続,*,*,*,*,発売,ハツバイ,ハツバイ
# 現行	名詞,一般,*,*,*,*,現行,ゲンコウ,ゲンコー
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# トップクラス	名詞,一般,*,*,*,*,トップクラス,トップクラス,トップクラス
# 性能	名詞,一般,*,*,*,*,性能,セイノウ,セイノー
# 製品	名詞,一般,*,*,*,*,製品,セイヒン,セイヒン
# 旧型	名詞,一般,*,*,*,*,旧型,キュウガタ,キューガタ
# 高速	名詞,一般,*,*,*,*,高速,コウソク,コーソク
# 化	名詞,接尾,サ変接続,*,*,*,化,カ,カ
# ポイント	名詞,一般,*,*,*,*,ポイント,ポイント,ポイント
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 風変わり	名詞,形容動詞語幹,*,*,*,*,風変わり,フウガワリ,フーガワリ
# レビュー	名詞,サ変接続,*,*,*,*,レビュー,レビュー,レビュー
# 程度	名詞,一般,*,*,*,*,程度,テイド,テイド
# 効果	名詞,一般,*,*,*,*,効果,コウカ,コーカ
# 期待	名詞,サ変接続,*,*,*,*,期待,キタイ,キタイ
# 大	名詞,接尾,一般,*,*,*,大,ダイ,ダイ
# 使用	名詞,サ変接続,*,*,*,*,使用,シヨウ,シヨー
# (	名詞,サ変接続,*,*,*,*,(,*,*
# インテル	名詞,固有名詞,組織,*,*,*,インテル,インテル,インテル
# )	名詞,サ変接続,*,*,*,*,),*,*
# ハイブリッド	名詞,一般,*,*,*,*,ハイブリッド,ハイブリッド,ハイブリッド
# これ	名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# 初期	名詞,一般,*,*,*,*,初期,ショキ,ショキ
# 費用	名詞,一般,*,*,*,*,費用,ヒヨウ,ヒヨー
# 更新	名詞,サ変接続,*,*,*,*,更新,コウシン,コーシン
# 費用	名詞,一般,*,*,*,*,費用,ヒヨウ,ヒヨー
# とも	名詞,接尾,一般,*,*,*,とも,トモ,トモ
# 無料	名詞,一般,*,*,*,*,無料,ムリョウ,ムリョー
# ジャストシステム	名詞,固有名詞,組織,*,*,*,ジャストシステム,ジャストシステム,ジャストシステム
# ヤモリ	名詞,一般,*,*,*,*,ヤモリ,ヤモリ,ヤモリ
# 目印	名詞,サ変接続,*,*,*,*,目印,メジルシ,メジルシ
# セキュリティ	名詞,一般,*,*,*,*,セキュリティ,セキュリティ,セキュリティ
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# 現在	名詞,副詞可能,*,*,*,*,現在,ゲンザイ,ゲンザイ
# 多く	名詞,副詞可能,*,*,*,*,多く,オオク,オーク
# ユーザー	名詞,一般,*,*,*,*,ユーザー,ユーザー,ユーザー
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# セキュリティ	名詞,一般,*,*,*,*,セキュリティ,セキュリティ,セキュリティ
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# 導入	名詞,サ変接続,*,*,*,*,導入,ドウニュウ,ドーニュー
# 過半数	名詞,一般,*,*,*,*,過半数,カハンスウ,カハンスー
# 毎年	名詞,副詞可能,*,*,*,*,毎年,マイトシ,マイトシ
# ,	名詞,サ変接続,*,*,*,*,,,*,*
# 円	名詞,一般,*,*,*,*,円,エン,エン
# 程度	名詞,接尾,一般,*,*,*,程度,テイド,テイド
# 更新	名詞,サ変接続,*,*,*,*,更新,コウシン,コーシン
# 費用	名詞,一般,*,*,*,*,費用,ヒヨウ,ヒヨー
# 手続き	名詞,サ変接続,*,*,*,*,手続き,テツヅキ,テツズキ
# 不満	名詞,一般,*,*,*,*,不満,フマン,フマン
# 有料	名詞,一般,*,*,*,*,有料,ユウリョウ,ユーリョー
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# 利用	名詞,サ変接続,*,*,*,*,利用,リヨウ,リヨー
# ユーザー	名詞,一般,*,*,*,*,ユーザー,ユーザー,ユーザー
# 割	名詞,一般,*,*,*,*,割,ワリ,ワリ
# 無料	名詞,一般,*,*,*,*,無料,ムリョウ,ムリョー
# セキュリティ	名詞,一般,*,*,*,*,セキュリティ,セキュリティ,セキュリティ
# ソフト	名詞,一般,*,*,*,*,ソフト,ソフト,ソフト
# 性能	名詞,一般,*,*,*,*,性能,セイノウ,セイノー
# 面	名詞,接尾,一般,*,*,*,面,メン,メン
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# 不安	名詞,形容動詞語幹,*,*,*,*,不安,フアン,フアン
# 導入	名詞,サ変接続,*,*,*,*,導入,ドウニュウ,ドーニュー
# 状況	名詞,一般,*,*,*,*,状況,ジョウキョウ,ジョーキョー
# テレビ	名詞,一般,*,*,*,*,テレビ,テレビ,テレビ
# 方	名詞,接尾,特殊,*,*,*,方,カタ,カタ
# 提案	名詞,サ変接続,*,*,*,*,提案,テイアン,テイアン
# 春	名詞,一般,*,*,*,*,春,ハル,ハル
# 連携	名詞,サ変接続,*,*,*,*,連携,レンケイ,レンケイ
# 年月日	名詞,一般,*,*,*,*,年月日,ネンガッピ,ネンガッピ
# 個人	名詞,一般,*,*,*,*,個人,コジン,コジン
# 向け	名詞,接尾,一般,*,*,*,向け,ムケ,ムケ
# デスク	名詞,一般,*,*,*,*,デスク,デスク,デスク
# トップ	名詞,一般,*,*,*,*,トップ,トップ,トップ
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# シリーズ	名詞,一般,*,*,*,*,シリーズ,シリーズ,シリーズ
# タイプ	名詞,一般,*,*,*,*,タイプ,タイプ,タイプ
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# 月日	名詞,一般,*,*,*,*,月日,ツキヒ,ツキヒ
# 販売	名詞,サ変接続,*,*,*,*,販売,ハンバイ,ハンバイ
# 発表	名詞,サ変接続,*,*,*,*,発表,ハッピョウ,ハッピョー
# 商品	名詞,一般,*,*,*,*,商品,ショウヒン,ショーヒン
# パワフル	名詞,一般,*,*,*,*,パワフル,パワフル,パワフル
# 録画	名詞,サ変接続,*,*,*,*,録画,ロクガ,ロクガ
# 機能	名詞,サ変接続,*,*,*,*,機能,キノウ,キノー
# 視聴	名詞,サ変接続,*,*,*,*,視聴,シチョウ,シチョー
# 録画	名詞,サ変接続,*,*,*,*,録画,ロクガ,ロクガ
# 機能	名詞,サ変接続,*,*,*,*,機能,キノウ,キノー
# 業界	名詞,一般,*,*,*,*,業界,ギョウカイ,ギョーカイ
# 人気	名詞,一般,*,*,*,*,人気,ニンキ,ニンキ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# 連携	名詞,サ変接続,*,*,*,*,連携,レンケイ,レンケイ
# つぶやき	名詞,一般,*,*,*,*,つぶやき,ツブヤキ,ツブヤキ
# プラス	名詞,一般,*,*,*,*,プラス,プラス,プラス
# 追加	名詞,サ変接続,*,*,*,*,追加,ツイカ,ツイカ
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# ならでは	名詞,接尾,一般,*,*,*,ならでは,ナラデハ,ナラデワ
# 機能	名詞,サ変接続,*,*,*,*,機能,キノウ,キノー
# 搭載	名詞,サ変接続,*,*,*,*,搭載,トウサイ,トーサイ
# スマート	名詞,固有名詞,人名,姓,*,*,スマート,スマート,スマート
# フォン	名詞,一般,*,*,*,*,フォン,フォン,フォン
# ホーム	名詞,一般,*,*,*,*,ホーム,ホーム,ホーム
# ネットワーク	名詞,一般,*,*,*,*,ネットワーク,ネットワーク,ネットワーク
# 対応	名詞,サ変接続,*,*,*,*,対応,タイオウ,タイオー
# 強化	名詞,サ変接続,*,*,*,*,強化,キョウカ,キョーカ
# 安心	名詞,サ変接続,*,*,*,*,安心,アンシン,アンシン
# 簡単	名詞,形容動詞語幹,*,*,*,*,簡単,カンタン,カンタン
# 快適	名詞,一般,*,*,*,*,快適,カイテキ,カイテキ
# デジタル	名詞,一般,*,*,*,*,デジタル,デジタル,デジタル
# エンターテイメント	名詞,一般,*,*,*,*,エンターテイメント,エンターテイメント,エンターテイメント
# 提案	名詞,サ変接続,*,*,*,*,提案,テイアン,テイアン
# 主要	名詞,形容動詞語幹,*,*,*,*,主要,シュヨウ,シュヨー
# モデル	名詞,一般,*,*,*,*,モデル,モデル,モデル
# 以下	名詞,非自立,副詞可能,*,*,*,以下,イカ,イカ
# 強化	名詞,サ変接続,*,*,*,*,強化,キョウカ,キョーカ
# 祭り	名詞,一般,*,*,*,*,祭り,マツリ,マツリ
# 出荷	名詞,サ変接続,*,*,*,*,出荷,シュッカ,シュッカ
# 式	名詞,接尾,一般,*,*,*,式,シキ,シキ
# レッツ	名詞,固有名詞,組織,*,*,*,レッツ,レッツ,レッツ
# ノート	名詞,一般,*,*,*,*,ノート,ノート,ノート
# 出荷	名詞,サ変接続,*,*,*,*,出荷,シュッカ,シュッカ
# 月日	名詞,一般,*,*,*,*,月日,ツキヒ,ツキヒ
# 発売	名詞,サ変接続,*,*,*,*,発売,ハツバイ,ハツバイ
# 出荷	名詞,サ変接続,*,*,*,*,出荷,シュッカ,シュッカ
# 式	名詞,接尾,一般,*,*,*,式,シキ,シキ
# 月日	名詞,一般,*,*,*,*,月日,ツキヒ,ツキヒ
# 国内	名詞,一般,*,*,*,*,国内,コクナイ,コクナイ
# 製造	名詞,サ変接続,*,*,*,*,製造,セイゾウ,セイゾー
# 拠点	名詞,一般,*,*,*,*,拠点,キョテン,キョテン
# 神戸	名詞,固有名詞,地域,一般,*,*,神戸,コウベ,コーベ
# 工場	名詞,一般,*,*,*,*,工場,コウジョウ,コージョー
# 同社	名詞,一般,*,*,*,*,同社,ドウシャ,ドーシャ
# パソコン	名詞,一般,*,*,*,*,パソコン,パソコン,パソコン
# 出荷	名詞,サ変接続,*,*,*,*,出荷,シュッカ,シュッカ
# 式	名詞,接尾,一般,*,*,*,式,シキ,シキ
# 製品	名詞,一般,*,*,*,*,製品,セイヒン,セイヒン
# 力	名詞,一般,*,*,*,*,力,チカラ,チカラ
# よう	名詞,接尾,一般,*,*,*,よう,ヨウ,ヨー
# エプソン	名詞,固有名詞,組織,*,*,*,エプソン,エプソン,エプソン
# 純正	名詞,一般,*,*,*,*,純正,ジュンセイ,ジュンセイ
# インク	名詞,一般,*,*,*,*,インク,インク,インク
# インク	名詞,一般,*,*,*,*,インク,インク,インク
# カートリッジ	名詞,一般,*,*,*,*,カートリッジ,カートリッジ,カートリッジ
# 色	名詞,接尾,一般,*,*,*,色,ショク,ショク
# セット	名詞,一般,*,*,*,*,セット,セット,セット
# エプソン	名詞,固有名詞,組織,*,*,*,エプソン,エプソン,エプソン
# 販売元	名詞,一般,*,*,*,*,販売元,ハンバイモト,ハンバイモト
# クチコミ	名詞,一般,*,*,*,*,クチコミ,*,*

# %% [markdown]
# #### 単語の出現回数をカウント

# %%
# 練習問題2
import collections

# 単語格納リスト
text = []

# フィルタ付き形態素解析
for token in a.analyze(reg_text):
    text.append(token.surface)

# 単語の出現回数をカウント
c = collections.Counter(text)
print(c)
# Out:
# Counter({'パソコン': 7, 'ソフト': 6, 'セキュリティ': 4, '出荷': 4, '旧式': 3, '最新': 3, '連携': 3, 'インテル': 3, 'の': 3, '費用': 3, '月日': 3, '機能': 3, '式': 3, '禁断': 2, 'パワーアップ': 2, '一挙': 2, 'テレビ': 2, '次': 2, '高速': 2, '化': 2, '(': 2, ')': 2, 'シリーズ': 2, '発売': 2, '性能': 2, '製品': 2, 'レビュー': 2, '程度': 2, '更新': 2, '無料': 2, 'ユーザー': 2, '導入': 2, '提案': 2, 'モデル': 2, '録画': 2, '強化': 2, 'エプソン': 2, 'インク': 2, 'チェック': 1, 'フラッシュ': 1, 'バック': 1, 'プロセッサ': 1, '登場': 1, '方法': 1, '話題': 1, '紹介': 1, '装着': 1, 'どれ': 1, '上': 1, '現行': 1, '中': 1, 'トップクラス': 1, '旧型': 1, 'ポイント': 1, '風変わり': 1, '効果': 1, '期待': 1, '大': 1, '使用': 1, 'ハイブリッド': 1, 'これ': 1, '初期': 1, 'とも': 1, 'ジャストシステム': 1, 'ヤモリ': 1, '目印': 1, '現在': 1, '多く': 1, '過半数': 1, '毎年': 1, ',': 1, '円': 1, '手続き': 1, '不満': 1, '有料': 1, '利用': 1, '割': 1, '面': 1, '不安': 1, '状況': 1, '方': 1, '春': 1, '年月日': 1, '個人': 1, '向け': 1, 'デスク': 1, 'トップ': 1, 'タイプ': 1, '販売': 1, '発表': 1, '商品': 1, 'パワフル': 1, '視聴': 1, '業界': 1, '人気': 1, 'つぶやき': 1, 'プラス': 1, '追加': 1, 'ならでは': 1, '搭載': 1, 'スマート': 1, 'フォン': 1, 'ホーム': 1, 'ネットワーク': 1, '対応': 1, '安心': 1, '簡単': 1, '快適': 1, 'デジタル': 1, 'エンターテイメント': 1, '主要': 1, '以下': 1, '祭り': 1, 'レッツ': 1, 'ノート': 1, '国内': 1, '製造': 1, '拠点': 1, '神戸': 1, '工場': 1, '同社': 1, '力': 1, 'よう': 1, '純正': 1, 'カートリッジ': 1, '色': 1, 'セット': 1, '販売元': 1, 'クチコミ': 1})
